# %% [markdown]
# ![Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.PNG](attachment:Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.PNG)

# %%
def strStr(haystack, needle):
    if haystack.count(needle)>=1:
        return haystack.index(needle)
    else:
        return -1

# %%
strStr("hello","ll")
# Out:
# 2

# %%
strStr("asddsaindexmsindex","index")
# Out:
# 6
