# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
def singleNumber(nums):
    setSum=sum(set(nums))
    listSum=sum(nums)
    return (setSum*3-listSum)//2

# %%
nums = [0,1,0,1,0,1,99]
singleNumber(nums)
# Out:
# 99

# %%
nums=[2,2,3,2]
singleNumber(nums)
# Out:
# 3
