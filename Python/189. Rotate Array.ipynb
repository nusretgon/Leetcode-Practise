# %% [markdown]
# ![rotate.PNG](attachment:rotate.PNG)

# %%
def rotate(nums, k):
    k=k%len(nums)
    nums = nums[-k:]+nums[:-k] # You have to add [:] after the nums in leetcode.
    return nums

# %%
nums = [1,2]
k=3
rotate(nums,k)
# Out:
# [2, 1]

# %%
nums = [1,2,3,4,5,6,7]
k=3
rotate(nums,k)
# Out:
# [5, 6, 7, 1, 2, 3, 4]
