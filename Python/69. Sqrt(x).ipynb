# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
def mySqrt(x):
    i=0
    while True:
        if (x>=i*i) and (x<i*i+2*i+1):
            return i
        i+=1

# %%
mySqrt(15)
# Out:
# 3

# %%
mySqrt(151231231231)
# Out:
# 388884

# %%
mySqrt(pow(1023421,2))
# Out:
# 1023421
