# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
def uniquePaths(m, n):
        import math
        return math.factorial(m+n-2)//(math.factorial(m-1)*(math.factorial(n-1)))

# %%
uniquePaths(3,7)
# Out:
# 28

# %% [markdown]
# ### Algorithm Design

# %% [markdown]
# ![WhatsApp%20G%C3%B6rsel%202023-01-27%20saat%2014.21.04-2.jpg](attachment:WhatsApp%20G%C3%B6rsel%202023-01-27%20saat%2014.21.04-2.jpg)

# %%
uniquePaths(8,4)
# Out:
# 120

# %% [markdown]
# ![2.PNG](attachment:2.PNG)
